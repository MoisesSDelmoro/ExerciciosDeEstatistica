# %%
import numpy as np
import pandas as pd

dataframe = pd.read_fwf('../Estatisticas'+'/data.txt',header=None,
names=["Router1", "Router2", "Router3", "Router4","Router5","Router6",
"Router7", "Room"])

# %% [markdown]
# # Sala 1

# %%
sala_1 = dataframe[dataframe['Room']==1]
boxplot  = sala_1.boxplot(column=["Router1", "Router2", "Router3", "Router4","Router5","Router6",
"Router7"])

# %% [markdown]
# # Sala 2

# %%
sala_2 = dataframe[dataframe['Room']==2]
boxplot  = sala_2.boxplot(column=["Router1", "Router2", "Router3", "Router4","Router5","Router6",
"Router7"])

# %% [markdown]
# # Sala 3

# %%
sala_3 = dataframe[dataframe['Room']==3]
boxplot  = sala_3.boxplot(column=["Router1", "Router2", "Router3", "Router4","Router5","Router6",
"Router7"])

# %% [markdown]
# # Sala 4

# %%
sala_4 = dataframe[dataframe['Room']==4]
boxplot  = sala_4.boxplot(column=["Router1", "Router2", "Router3", "Router4","Router5","Router6",
"Router7"])

# %% [markdown]
# # Correlação

# %%
dataframe.corr()
# Out:
#           Router1   Router2   Router3   Router4   Router5   Router6   Router7  \
# Router1  1.000000 -0.003298  0.050814  0.921025 -0.244932  0.718429  0.686955
# Router2 -0.003298  1.000000  0.282211  0.014604  0.200469  0.074002  0.048336
# Router3  0.050814  0.282211  1.000000  0.078292  0.618984 -0.091622 -0.073141
# Router4  0.921025  0.014604  0.078292  1.000000 -0.236021  0.706039  0.673294
# Router5 -0.244932  0.200469  0.618984 -0.236021  1.000000 -0.416049 -0.361621
# Router6  0.718429  0.074002 -0.091622  0.706039 -0.416049  1.000000  0.723172
# Router7  0.686955  0.048336 -0.073141  0.673294 -0.361621  0.723172  1.000000
# Room    -0.058061  0.143254  0.688467 -0.039363  0.820530 -0.360171 -0.305075
#
#              Room
# Router1 -0.058061
# Router2  0.143254
# Router3  0.688467
# Router4 -0.039363
# Router5  0.820530
# Router6 -0.360171
# Router7 -0.305075
# Room     1.000000
